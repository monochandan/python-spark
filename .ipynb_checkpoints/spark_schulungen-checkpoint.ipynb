# %%
# !pip install findspark
# Out:
# ...
# WARNING: You are using pip version 21.2.3; however, version 24.1.1 is available.
# You should consider upgrading via the 'C:\Users\looka\OneDrive\Documents\pySpark\spark_env\Scripts\python.exe -m pip install --upgrade pip' command.

# %%
# !pip install pyspark
# Out:
# ...
# Using legacy 'setup.py install' for pyspark, since package 'wheel' is not installed.
# ...
#     Running setup.py install for pyspark: started
#     Running setup.py install for pyspark: still running...
#     Running setup.py install for pyspark: finished with status 'done'
# ...
# WARNING: You are using pip version 21.2.3; however, version 24.1.1 is available.
# You should consider upgrading via the 'C:\Users\looka\OneDrive\Documents\pySpark\spark_env\Scripts\python.exe -m pip install --upgrade pip' command.

# %%
# !pip install plotly
# Out:
# ...
# WARNING: You are using pip version 21.2.3; however, version 24.1.1 is available.
# You should consider upgrading via the 'C:\Users\looka\OneDrive\Documents\pySpark\spark_env\Scripts\python.exe -m pip install --upgrade pip' command.

# %%
# !pip install matplotlib
# Out:
# ...
#   Using cached matplotlib-3.9.0-cp39-cp39-win_amd64.whl (7.9 MB)
# ...
#   Using cached pyparsing-3.1.2-py3-none-any.whl (103 kB)
# ...
#   Using cached kiwisolver-1.4.5-cp39-cp39-win_amd64.whl (56 kB)
# ...
#   Using cached contourpy-1.2.1-cp39-cp39-win_amd64.whl (182 kB)
# ...
#   Using cached numpy-2.0.0-cp39-cp39-win_amd64.whl (16.5 MB)
# ...
#   Using cached importlib_resources-6.4.0-py3-none-any.whl (38 kB)
# ...
#   Using cached fonttools-4.53.0-cp39-cp39-win_amd64.whl (2.2 MB)
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# ...
# WARNING: You are using pip version 21.2.3; however, version 24.1.1 is available.
# You should consider upgrading via the 'C:\Users\looka\OneDrive\Documents\pySpark\spark_env\Scripts\python.exe -m pip install --upgrade pip' command.

# %%
# !pip install pandas
# Out:
# ...
#   Using cached pandas-2.2.2-cp39-cp39-win_amd64.whl (11.6 MB)
# ...
#   Using cached pytz-2024.1-py2.py3-none-any.whl (505 kB)
# ...
#   Using cached tzdata-2024.1-py2.py3-none-any.whl (345 kB)
# ...
# WARNING: You are using pip version 21.2.3; however, version 24.1.1 is available.
# You should consider upgrading via the 'C:\Users\looka\OneDrive\Documents\pySpark\spark_env\Scripts\python.exe -m pip install --upgrade pip' command.

# %%
import findspark
from functools import reduce
from pyspark import SparkContext
from pyspark.sql import SparkSession, Window, Row
from pyspark.sql.functions import *
from pyspark.sql.types import *
import plotly as py
import matplotlib.pyplot as plt

# %%
# entry point - creating basic spark session using SparkSession.builder 
spark = SparkSession.builder.appName("erstespark").getOrCreate()

# %%
## function for loading the dataframe
# https://spark.apache.org/docs/latest/sql-data-sources-generic-options.html
def load_dataframe(f):
    df = spark.read.format('csv').options(header = 'true').load(f)
    return df

# %%
## creating a dataframe
matches = load_dataframe('./data/Matches.csv')
matches.limit(10).show()
# Out:
# +--------+---+------+----------+--------------+--------------+----+----+---+
# |Match_ID|Div|Season|      Date|      HomeTeam|      AwayTeam|FTHG|FTAG|FTR|
# +--------+---+------+----------+--------------+--------------+----+----+---+
# |       1| D2|  2009|2010-04-04|    Oberhausen|Kaiserslautern|   2|   1|  H|
# |       2| D2|  2009|2009-11-01|   Munich 1860|Kaiserslautern|   0|   1|  A|
# |       3| D2|  2009|2009-10-04| Frankfurt FSV|Kaiserslautern|   1|   1|  D|
# |       4| D2|  2009|2010-02-21| Frankfurt FSV|     Karlsruhe|   2|   1|  H|
# |       5| D2|  2009|2009-12-06|         Ahlen|     Karlsruhe|   1|   3|  A|
# |       6| D2|  2009|2010-04-03|  Union Berlin|     Karlsruhe|   1|   1|  D|
# |       7| D2|  2009|2009-08-14|     Paderborn|     Karlsruhe|   2|   0|  H|
# |       8| D2|  2009|2010-03-08|     Bielefeld|     Karlsruhe|   0|   1|  A|
# |       9| D2|  2009|2009-09-26|Kaiserslautern|     Karlsruhe|   2|   0|  H|
# ...

# %%
## 
matches.columns
# Out:
# ['Match_ID',
#  'Div',
#  'Season',
#  'Date',
#  'HomeTeam',
#  'AwayTeam',
#  'FTHG',
#  'FTAG',
#  'FTR']

# %%
alt_columns = matches.columns[-3:]
neue_columns = ["Home_Team_Goal", "Away_Team_Goal", "Final_Result"]

# %%
alt_neue_columns = [*zip(alt_columns, neue_columns)]

# %%
alt_neue_columns
# Out:
# [('FTHG', 'Home_Team_Goal'),
#  ('FTAG', 'Away_Team_Goal'),
#  ('FTR', 'Final_Result')]

# %%
# https://spark.apache.org/docs/latest/api/python/reference/pyspark.sql/api/pyspark.sql.DataFrame.withColumnRenamed.html
for alt_columns, neue_columns in alt_neue_columns:
    matches = matches.withColumnRenamed(alt_columns, neue_columns)

# %%
matches.columns
# Out:
# ['Match_ID',
#  'Div',
#  'Season',
#  'Date',
#  'HomeTeam',
#  'AwayTeam',
#  'Home_Team_Goal',
#  'Away_Team_Goal',
#  'Final_Result']

# %%
matches.limit(5).toPandas()
# Out:
#   Match_ID Div Season        Date       HomeTeam        AwayTeam  \
# 0        1  D2   2009  2010-04-04     Oberhausen  Kaiserslautern
# 1        2  D2   2009  2009-11-01    Munich 1860  Kaiserslautern
# 2        3  D2   2009  2009-10-04  Frankfurt FSV  Kaiserslautern
# 3        4  D2   2009  2010-02-21  Frankfurt FSV       Karlsruhe
# 4        5  D2   2009  2009-12-06          Ahlen       Karlsruhe
#
#   Home_Team_Goal Away_Team_Goal Final_Result
# 0              2              1            H
# 1              0              1            A
# 2              1              1            D
# 3              2              1            H
# 4              1              3            A

# %% [markdown]
# #### Frage 1: Who are the winners of the D1 division in the Germany Football Association (Bundesliga) in the 2010 to 2016?

# %%
## filter division with D1, last decade (2010 - 2019)
## https://spark.apache.org/docs/latest/api/python/reference/pyspark.sql/api/pyspark.sql.DataFrame.filter.html
bundesliga = matches.filter((col('Season') >= 2010) & (col('Season') <= 2016) & (col('Div') == 'D1'))
# bundesliga.limit(5).toPandas()

## indicate the winner loser and drow in simple way
## https://spark.apache.org/docs/latest/api/python/reference/pyspark.sql/api/pyspark.sql.DataFrame.withColumn.html
bundesliga = bundesliga.withColumn('HomeTeamWin', when(col('Final_Result') == 'H', 1).otherwise(0)) \
                        .withColumn('AwayTeamWin', when(col('Final_Result') == 'A', 1).otherwise(0)) \
                        .withColumn('Drow', when(col('Final_Result') == 'D', 1).otherwise(0))

# %%
#bundesliga.limit(5).toPandas()
bundesliga.columns
# Out:
# ['Match_ID',
#  'Div',
#  'Season',
#  'Date',
#  'HomeTeam',
#  'AwayTeam',
#  'Home_Team_Goal',
#  'Away_Team_Goal',
#  'Final_Result',
#  'HomeTeamWin',
#  'AwayTeamWin',
#  'Drow']

# %%
# https://spark.apache.org/docs/latest/api/python/reference/pyspark.sql/api/pyspark.sql.GroupedData.agg.html
home = bundesliga.groupby('Season', 'HomeTeam') \
                .agg(sum('HomeTeamWin').alias('TotalHomeWin'),
                     sum('AwayTeamWin').alias('TotalHomeLoss'),
                     sum('Drow').alias('TotalHomeDrow'),
                     sum('Home_Team_Goal').alias('Home_Scored_Goals'),
                     sum('Away_Team_Goal').alias('Home_Against_Goals')) \
                .withColumnRenamed('HomeTeam', 'Team') 

home.toPandas()
# Out:
#     Season                Team  TotalHomeWin  TotalHomeLoss  TotalHomeDrow  \
# 0     2011             Hamburg             3              7              7
# 1     2015              Hertha             9              3              5
# 2     2012            Hannover             9              3              5
# 3     2014           Paderborn             4              7              6
# 4     2012          M'gladbach             8              4              5
# ..     ...                 ...           ...            ...            ...
# 121   2012  Fortuna Dusseldorf             5              6              6
# 122   2014            Dortmund             9              5              3
# 123   2015             Hamburg             5              8              4
# 124   2016       Bayern Munich            13              0              4
# 125   2013            Augsburg             9              5              3
#
#      Home_Scored_Goals  Home_Against_Goals
# ...

# %%
away = bundesliga.groupby('Season', 'AwayTeam') \
                .agg(sum('AwayTeamWin').alias('TotalAwayWin'),
                     sum('HomeTeamWin').alias('TotalAwayLoss'),
                     sum('Drow').alias('TotalAwayDrow'),
                     sum('Away_Team_Goal').alias('Away_Scored_Goals'),
                     sum('Home_Team_Goal').alias('Away_Against_Goals')) \
                .withColumnRenamed('AwayTeam', 'Team')

# %%
# Werder Bremen	
bundesliga.filter((col('HomeTeam') == 'Werder Bremen') | (col('AwayTeam') == 'Werder Bremen')).show()
# Out:
# +--------+---+------+----------+-------------+--------------+--------------+--------------+------------+-----------+-----------+----+
# |Match_ID|Div|Season|      Date|     HomeTeam|      AwayTeam|Home_Team_Goal|Away_Team_Goal|Final_Result|HomeTeamWin|AwayTeamWin|Drow|
# +--------+---+------+----------+-------------+--------------+--------------+--------------+------------+-----------+-----------+----+
# |     489| D1|  2010|2011-01-29|Werder Bremen| Bayern Munich|             1|             3|           A|          0|          1|   0|
# |     498| D1|  2010|2011-05-07|Werder Bremen|      Dortmund|             2|             0|           H|          1|          0|   0|
# |     542| D1|  2010|2010-11-13|Werder Bremen| Ein Frankfurt|             0|             0|           D|          0|          0|   1|
# |     560| D1|  2010|2010-08-28|Werder Bremen|       FC Koln|             4|             2|           H|          1|          0|   0|
# ...

# %%
away.toPandas()
# Out:
#     Season                Team  TotalAwayWin  TotalAwayLoss  TotalAwayDrow  \
# 0     2011             Hamburg             5              7              5
# 1     2015              Hertha             5              9              3
# 2     2012            Hannover             4             12              1
# 3     2014           Paderborn             3             10              4
# 4     2012          M'gladbach             4              7              6
# ..     ...                 ...           ...            ...            ...
# 121   2012  Fortuna Dusseldorf             2             12              3
# 122   2014            Dortmund             4              9              4
# 123   2015             Hamburg             6              7              4
# 124   2016       Bayern Munich            12              2              3
# 125   2013            Augsburg             6              7              4
#
#      Away_Scored_Goals  Away_Against_Goals
# ...

# %%
print(away.columns)
print(home.columns)
# Out:
# ['Season', 'Team', 'TotalAwayWin', 'TotalAwayLoss', 'TotalAwayDrow', 'Away_Scored_Goals', 'Away_Against_Goals']
# ['Season', 'Team', 'TotalHomeWin', 'TotalHomeLoss', 'TotalHomeDrow', 'Home_Scored_Goals', 'Home_Against_Goals']

# %%
## inner join :https://spark.apache.org/docs/latest/api/python/reference/pyspark.pandas/api/pyspark.pandas.DataFrame.join.html?highlight=inner%20join
## window : https://spark.apache.org/docs/latest/api/python/reference/pyspark.sql/api/pyspark.sql.Window.orderBy.html
window = ['Season']
window = Window.partitionBy(window).orderBy(col('WinPercentage').desc(), col('GoalDifference').desc())
table = home.join(away, ['Team', 'Season'], how ='inner') \
        .withColumn('GoalsScored', col('Home_Scored_Goals') + col('Away_Scored_Goals')) \
        .withColumn('GoalsAgainst', col('Home_Against_Goals') + col('Away_Against_Goals')) \
        .withColumn('GoalDifference', col('GoalsScored') - col('GoalsAgainst')) \
        .withColumn('Win', col('TotalHomeWin') + col('TotalAwayWin')) \
        .withColumn('Loss', col('TotalHomeLoss') + col('TotalAwayLoss')) \
        .withColumn('Drow', col('TotalHomeDrow') + col('TotalAwayDrow')) \
        .withColumn('WinPercentage', round((100 * col('Win') /(col('Win') + col('Loss') + col('Drow'))), 2))\
        .drop('Away_Scored_Goals', 'Away_Against_Goals', 'Home_Scored_Goals', 'Home_Against_Goals')\
        .drop('TotalAwayWin', 'TotalHomeWin', 'TotalHomeLoss', 'TotalAwayLoss', 'TotalAwayDrow', 'TotalHomeDrow')\
        .withColumn('TeamPosition', rank().over(window))

# %%
table.toPandas()
# Out:
#               Team Season  GoalsScored  GoalsAgainst  GoalDifference  Win  \
# 0         Dortmund   2010         67.0          22.0            45.0   23
# 1       Leverkusen   2010         64.0          44.0            20.0   20
# 2    Bayern Munich   2010         81.0          40.0            41.0   19
# 3         Hannover   2010         49.0          45.0             4.0   19
# 4            Mainz   2010         52.0          39.0            13.0   18
# ..             ...    ...          ...           ...             ...  ...
# 121      Wolfsburg   2016         34.0          52.0           -18.0   10
# 122        Hamburg   2016         33.0          61.0           -28.0   10
# 123       Augsburg   2016         35.0          51.0           -16.0    9
# 124     Ingolstadt   2016         36.0          57.0           -21.0    8
# 125      Darmstadt   2016         28.0          63.0           -35.0    7
#
#      Loss  Drow  WinPercentage  TeamPosition
# ...

# %%
table = table.filter(col('TeamPosition') == 1).orderBy(asc('Season'))
table.toPandas()
# Out:
#             Team Season  GoalsScored  GoalsAgainst  GoalDifference  Win  Loss  \
# 0       Dortmund   2010         67.0          22.0            45.0   23     5
# 1       Dortmund   2011         80.0          25.0            55.0   25     3
# 2  Bayern Munich   2012         98.0          18.0            80.0   29     1
# 3  Bayern Munich   2013         94.0          23.0            71.0   29     2
# 4  Bayern Munich   2014         80.0          18.0            62.0   25     5
# 5  Bayern Munich   2015         80.0          17.0            63.0   28     2
# 6  Bayern Munich   2016         89.0          22.0            67.0   25     2
#
#    Drow  WinPercentage  TeamPosition
# 0     6          67.65             1
# 1     6          73.53             1
# 2     4          85.29             1
# 3     3          85.29             1
# 4     4          73.53             1
# 5     4          82.35             1
# 6     7          73.53             1

# %%
table.groupby('Team').agg(count('Team').alias("TotalChampionShips"),
                        avg('WinPercentage').alias('AvgWinPct'),
                         avg('GoalDifference').alias('AvgGoalDifference'),
                         avg('Win').alias('AvgWin'),
                         avg('Loss').alias('AvgLoss'),
                         avg('Drow').alias('AvgDrow'))\
                    .orderBy(desc("TotalChampionShips")).toPandas().round(1)
# Out:
#             Team  TotalChampionShips  AvgWinPct  AvgGoalDifference  AvgWin  \
# 0  Bayern Munich                   5       80.0               68.6    27.2
# 1       Dortmund                   2       70.6               50.0    24.0
#
#    AvgLoss  AvgDrow
# 0      2.4      4.4
# 1      4.0      6.0

# %% [markdown]
# #### Frage 2: Which teams have been relegated in that 6 years?

# %%
teams = load_dataframe('./data/Teams.csv')
teams_in_matches = load_dataframe('./data/Teams_in_Matches.csv')
teams_unique = load_dataframe('./data/Teams_Unique.csv')

# %%
print(matches.columns)
print(teams.columns)
print(teams_in_matches.columns)
print(teams_unique.columns)
# Out:
# ['Match_ID', 'Div', 'Season', 'Date', 'HomeTeam', 'AwayTeam', 'Home_Team_Goal', 'Away_Team_Goal', 'Final_Result']
# ['Season', 'TeamName', 'KaderHome', 'AvgAgeHome', 'ForeignPlayersHome', 'OverallMarketValueHome', 'AvgMarketValueHome', 'StadiumCapacity']
# ['Match_ID', 'Unique_Team_ID']
# ['TeamName', 'Unique_Team_ID']

# %%
teams.limit(5).toPandas()
# Out:
#   Season       TeamName KaderHome AvgAgeHome ForeignPlayersHome  \
# 0   2017  Bayern Munich        27         26                 15
# 1   2017       Dortmund        33         25                 18
# 2   2017     Leverkusen        31         24                 15
# 3   2017     RB Leipzig        30         23                 15
# 4   2017     Schalke 04        29         24                 17
#
#   OverallMarketValueHome AvgMarketValueHome StadiumCapacity
# 0              597950000           22150000           75000
# 1              416730000           12630000           81359
# 2              222600000            7180000           30210
# 3              180130000            6000000           42959
# 4              179550000            6190000           62271

# %%
table.toPandas()
# Out:
#             Team Season  GoalsScored  GoalsAgainst  GoalDifference  Win  Loss  \
# 0       Dortmund   2010         67.0          22.0            45.0   23     5
# 1       Dortmund   2011         80.0          25.0            55.0   25     3
# 2  Bayern Munich   2012         98.0          18.0            80.0   29     1
# 3  Bayern Munich   2013         94.0          23.0            71.0   29     2
# 4  Bayern Munich   2014         80.0          18.0            62.0   25     5
# 5  Bayern Munich   2015         80.0          17.0            63.0   28     2
# 6  Bayern Munich   2016         89.0          22.0            67.0   25     2
#
#    Drow  WinPercentage  TeamPosition
# 0     6          67.65             1
# 1     6          73.53             1
# 2     4          85.29             1
# 3     3          85.29             1
# 4     4          73.53             1
# 5     4          82.35             1
# 6     7          73.53             1

# %%
## relegated last three teams
relegated = table.filter((col('TeamPosition') == 16) | (col('TeamPosition') == 17) | (col('TeamPosition') == 18)).orderBy(asc('Season'))

# %%
## teams of 2010
relegated.filter(col('Season') == 2010).toPandas()
# Out:
# Empty DataFrame
# Columns: [Team, Season, GoalsScored, GoalsAgainst, GoalDifference, Win, Loss, Drow, WinPercentage, TeamPosition]
# Index: []

# %% [markdown]
# #### Frage 3: Does Octoberfest affect the performance of Bundesliga?

# %%
bundesliga.toPandas()
# Out:
#      Match_ID Div Season        Date        HomeTeam       AwayTeam  \
# 0         480  D1   2010  2010-09-21      Hoffenheim  Bayern Munich
# 1         481  D1   2010  2011-01-15       Wolfsburg  Bayern Munich
# 2         482  D1   2010  2010-12-19       Stuttgart  Bayern Munich
# 3         483  D1   2010  2011-04-23   Ein Frankfurt  Bayern Munich
# 4         484  D1   2010  2010-08-27  Kaiserslautern  Bayern Munich
# ...       ...  ..    ...         ...             ...            ...
# 2137     4742  D1   2016  2016-09-25         FC Koln     RB Leipzig
# 2138     4743  D1   2016  2016-12-10      Ingolstadt     RB Leipzig
# 2139     4744  D1   2016  2017-02-04        Dortmund     RB Leipzig
# 2140     4745  D1   2016  2016-09-17         Hamburg     RB Leipzig
# 2141     4746  D1   2016  2017-05-20   Ein Frankfurt     RB Leipzig
#
#      Home_Team_Goal Away_Team_Goal Final_Result  HomeTeamWin  AwayTeamWin  \
# 0                 1              2            A            0            1
# ...

# %%
bundesliga.columns
# Out:
# ['Match_ID',
#  'Div',
#  'Season',
#  'Date',
#  'HomeTeam',
#  'AwayTeam',
#  'Home_Team_Goal',
#  'Away_Team_Goal',
#  'Final_Result',
#  'HomeTeamWin',
#  'AwayTeamWin',
#  'Drow']

# %%
## .withColumn('Year', year(col('Date')))\
##             .groupby('Month', 'Year')\

octo_fest = bundesliga.filter(col('Div') == 'D1')\
            .filter((col('Season') >= 2010) & (col('Season') <= 2016))\
            .withColumn('Month', month(col('Date'))) \
            .groupby('Month')\
            .agg(sum(col('Home_Team_Goal') + col('Away_Team_Goal')).alias('Goals'),
                    sum('Drow').alias('GameDrow'),
                    count(col('Final_Result')).alias('Total'),
                    count(col('Match_ID')).alias('Monthly_Total_Matches'))\
            .withColumn('Goals_to_game_ratio', round(col('Goals')/col('Total'), 1))\
            .withColumn('GameDrow_to_game_ratio', round(col('GameDrow')/col('Total'), 1))

# %%
octo_fest.toPandas()
# Out:
#    Month  Goals  GameDrow  Total  Monthly_Total_Matches  Goals_to_game_ratio  \
# 0     12  561.0        60    208                    208                  2.7
# 1      1  311.0        26    117                    117                  2.7
# 2      3  749.0        59    252                    252                  3.0
# 3      5  490.0        33    154                    154                  3.2
# 4      9  724.0        59    246                    246                  2.9
# 5      4  846.0        72    297                    297                  2.8
# 6      8  448.0        33    152                    152                  2.9
# 7     10  641.0        53    222                    222                  2.9
# 8     11  729.0        50    233                    233                  3.1
# 9      2  721.0        66    261                    261                  2.8
#
#    GameDrow_to_game_ratio
# 0                     0.3
# 1                     0.2
# 2                     0.2
# ...

# %%
#octo_month_df.Month.tolist()

# %%
import calendar

# %%
octo_month_df = octo_fest.toPandas()
octo_month_df = octo_month_df.sort_values('Month')
octo_month_df['Month'] = [calendar.month_name[val] for val in octo_month_df.Month.tolist()]
octo_month_df.set_index('Month', drop = True, inplace = True)
octo_month_df['Goals_to_game_ratio'].plot.bar(rot = 45, color = 'Green', figsize = (12, 4))
plt.ylabel('Goals_to_game_ratio')
plt.show()

# %%
octo_month_df['GameDrow_to_game_ratio'].plot.bar(rot = 45, color = 'Blue', figsize = (12, 4))
plt.ylabel('GameDrow_to_game_ratio')
plt.show()

# %%
## monthly match played
octo_month_df['Monthly_Total_Matches'].plot.bar(rot = 45, color = 'red', figsize = (12, 4))
plt.ylabel('Monthly_Total_Matches')
plt.show()

# %%
## YEARLY
octo_fest_yearly = bundesliga.filter(col('Div') == 'D1')\
            .filter((col('Season') >= 2010) & (col('Season') <= 2016))\
            .withColumn('Year', year(col('Date')))\
            .groupby('Year')\
            .agg(sum(col('Home_Team_Goal') + col('Away_Team_Goal')).alias('Goals'),
                    sum('Drow').alias('GameDrow'),
                    count(col('Final_Result')).alias('Total'),
                    count(col('Match_ID')).alias('Yearly_Total_Matches'))\
            .withColumn('Goals_to_game_ratio', round(col('Goals')/col('Total'), 1))\
            .withColumn('GameDrow_to_game_ratio', round(col('GameDrow')/col('Total'), 1))

# %%
octo_year_df = octo_fest_yearly.toPandas()
octo_year_df = octo_year_df.sort_values('Year')
##octo_month_df['Month'] = [calendar.month_name[val] for val in octo_month_df.Month.tolist()]
octo_year_df.set_index('Year', drop = True, inplace = True)
octo_year_df['Goals_to_game_ratio'].plot.bar(rot = 45, color = 'Green', figsize = (12, 4))
plt.ylabel('Goals_to_game_ratio')
plt.show()

# %%
octo_year_df['GameDrow_to_game_ratio'].plot.bar(rot = 45, color = 'Blue', figsize = (12, 4))
plt.ylabel('GameDrow_to_game_ratio')
plt.show()

# %%
## yearly played matches
octo_year_df['Yearly_Total_Matches'].plot.bar(rot = 45, color = 'red', figsize = (12, 4))
plt.ylabel('Yearly_Total_Matches')
plt.show()

# %%
## YEARLY October
octo_fest_yearly_monthly = bundesliga.filter(col('Div') == 'D1')\
            .filter((col('Season') >= 2010) & (col('Season') <= 2016))\
            .withColumn('Year', year(col('Date')))\
            .withColumn('Month', month(col('Date')))\
            .groupby('Year', 'Month')\
            .agg(sum(col('Home_Team_Goal') + col('Away_Team_Goal')).alias('Goals'),
                    sum('Drow').alias('GameDrow'),
                    count(col('Final_Result')).alias('Total'),
                    count(col('Match_ID')).alias('Total_Matches'))\
            .withColumn('Goals_to_game_ratio', round(col('Goals')/col('Total'), 1))\
            .withColumn('GameDrow_to_game_ratio', round(col('GameDrow')/col('Total'), 1))
octo_fest_yearly_monthly.toPandas()
# Out:
#     Year  Month  Goals  GameDrow  Total  Total_Matches  Goals_to_game_ratio  \
# 0   2012     10   77.0         6     27             27                  2.9
# 1   2010     12   76.0         6     27             27                  2.8
# 2   2015      2  127.0        12     45             45                  2.8
# 3   2017      3   80.0         7     28             28                  2.9
# 4   2014      4  105.0         8     36             36                  2.9
# ..   ...    ...    ...       ...    ...            ...                  ...
# 65  2011      1   63.0         6     27             27                  2.3
# 66  2015      5   93.0         7     36             36                  2.6
# 67  2017      1   48.0         3     18             18                  2.7
# 68  2011      9   83.0         3     28             28                  3.0
# 69  2016      3  106.0         9     36             36                  2.9
#
#     GameDrow_to_game_ratio
# 0                      0.2
# ...

# %%
new_octo_fest_yearly_monthly = octo_fest_yearly_monthly.filter((col('Month') == 10))
new_octo_fest_yearly_monthly.toPandas()
# Out:
#    Year  Month  Goals  GameDrow  Total  Total_Matches  Goals_to_game_ratio  \
# 0  2012     10   77.0         6     27             27                  2.9
# 1  2014     10   81.0         6     28             28                  2.9
# 2  2013     10   84.0         9     27             27                  3.1
# 3  2016     10   89.0        10     35             35                  2.5
# 4  2015     10  101.0         7     34             34                  3.0
# 5  2010     10  112.0         6     36             36                  3.1
# 6  2011     10   97.0         9     35             35                  2.8
#
#    GameDrow_to_game_ratio
# 0                     0.2
# 1                     0.2
# 2                     0.3
# 3                     0.3
# 4                     0.2
# 5                     0.2
# 6                     0.3

# %%
## october matches in 7 years
new_octo_fest_yearly_monthly_df = new_octo_fest_yearly_monthly.toPandas()
new_octo_fest_yearly_monthly_df = new_octo_fest_yearly_monthly_df.sort_values('Year')
ax = new_octo_fest_yearly_monthly_df['Total_Matches'].plot(kind = 'bar',rot = 45, color = 'Pink', figsize = (12, 4))
plt.ylabel('Total Matches in October Month')
plt.xlabel('Year')
plt.xticks(range(len(new_octo_fest_yearly_monthly_df['Year'])), new_octo_fest_yearly_monthly_df['Year'])

# The enumerate function is used to loop over the Total_Matches column and get both the index and the value of each bar
for index, value in enumerate(new_octo_fest_yearly_monthly_df['Total_Matches']):
        # xy=(index, value): Specifies the position of the annotation (at the top of the bar
        # xytext=(0, 3): Offsets the text by 3 points above the bar
        # textcoords='offset points': Ensures the text is offset by the specified amount.
        # ha='center': Horizontally aligns the text in the center of the bar.
    ax.annotate(str(value), xy=(index, value), xytext = (0, 3), textcoords = 'offset points', ha = 'center')
    
plt.show()

# %% [markdown]
# #### Frage 4: Which season of Bundesliga was the most competitive in the last decade?

# %%
bundesliga.limit(5).toPandas()
# Out:
#   Match_ID Div Season        Date        HomeTeam       AwayTeam  \
# 0      480  D1   2010  2010-09-21      Hoffenheim  Bayern Munich
# 1      481  D1   2010  2011-01-15       Wolfsburg  Bayern Munich
# 2      482  D1   2010  2010-12-19       Stuttgart  Bayern Munich
# 3      483  D1   2010  2011-04-23   Ein Frankfurt  Bayern Munich
# 4      484  D1   2010  2010-08-27  Kaiserslautern  Bayern Munich
#
#   Home_Team_Goal Away_Team_Goal Final_Result  HomeTeamWin  AwayTeamWin  Drow
# 0              1              2            A            0            1     0
# 1              1              1            D            0            0     1
# 2              3              5            A            0            1     0
# 3              1              1            D            0            0     1
# 4              2              0            H            1            0     0

# %%
## calculate for home team each game win = 3 point, loss = 0, drow = 1
bundesliga = bundesliga.withColumn('HomePoints',
                                     when(col('HomeTeamWin') == 1, 3)
                                    .when(col('Drow') == 1, 1)
                                    .otherwise(0)
                    )

# %%
bundesliga.limit(5).toPandas()
# Out:
#   Match_ID Div Season        Date        HomeTeam       AwayTeam  \
# 0      480  D1   2010  2010-09-21      Hoffenheim  Bayern Munich
# 1      481  D1   2010  2011-01-15       Wolfsburg  Bayern Munich
# 2      482  D1   2010  2010-12-19       Stuttgart  Bayern Munich
# 3      483  D1   2010  2011-04-23   Ein Frankfurt  Bayern Munich
# 4      484  D1   2010  2010-08-27  Kaiserslautern  Bayern Munich
#
#   Home_Team_Goal Away_Team_Goal Final_Result  HomeTeamWin  AwayTeamWin  Drow  \
# 0              1              2            A            0            1     0
# 1              1              1            D            0            0     1
# 2              3              5            A            0            1     0
# 3              1              1            D            0            0     1
# 4              2              0            H            1            0     0
#
#    HomePoints
# 0           0
# 1           1
# 2           0
# 3           1
# 4           3

# %%
## calculate for away team each game win = 3 point, loss = 0, drow = 1
bundesliga = bundesliga.withColumn('AwayPoints',
                    when(col('AwayTeamWin') == 1, 3)
                    .when(col('Drow') == 1, 1)
                    .otherwise(0)
                )

# %%
bundesliga.limit(5).toPandas()
# Out:
#   Match_ID Div Season        Date        HomeTeam       AwayTeam  \
# 0      480  D1   2010  2010-09-21      Hoffenheim  Bayern Munich
# 1      481  D1   2010  2011-01-15       Wolfsburg  Bayern Munich
# 2      482  D1   2010  2010-12-19       Stuttgart  Bayern Munich
# 3      483  D1   2010  2011-04-23   Ein Frankfurt  Bayern Munich
# 4      484  D1   2010  2010-08-27  Kaiserslautern  Bayern Munich
#
#   Home_Team_Goal Away_Team_Goal Final_Result  HomeTeamWin  AwayTeamWin  Drow  \
# 0              1              2            A            0            1     0
# 1              1              1            D            0            0     1
# 2              3              5            A            0            1     0
# 3              1              1            D            0            0     1
# 4              2              0            H            1            0     0
#
#    HomePoints  AwayPoints
# 0           0           3
# 1           1           1
# 2           0           3
# ...

# %%
## Aggregate points for each team and each season
home_points = bundesliga.groupBy('Season', 'HomeTeam').agg(sum('HomePoints').alias('TotalHomePoints'))
away_points = bundesliga.groupBy('Season', 'AwayTeam').agg(sum('AwayPoints').alias('TotalAwayPoints'))

# %%
bundesliga.columns
# Out:
# ['Match_ID',
#  'Div',
#  'Season',
#  'Date',
#  'HomeTeam',
#  'AwayTeam',
#  'Home_Team_Goal',
#  'Away_Team_Goal',
#  'Final_Result',
#  'HomeTeamWin',
#  'AwayTeamWin',
#  'Drow',
#  'HomePoints',
#  'AwayPoints']

# %%
# hamburg_h = bundesliga.filter((col('HomeTeam') == 'Hamburg') | (col('AwayTeam') == 'Hamburg'))\
#                     .filter(col('Season') == 2011)\
#                     .groupBy('HomeTeam', 'AwayTeam')\
#                     .agg(sum('HomeTeamWin') + sum('AwayTeamWin') + sum('Drow'))
# hamburg_h.toPandas()

# %%
hamburg_a = away_points.filter(col('AwayTeam') == 'Hamburg')\
                    .filter(col('Season') == 2011)
hamburg.toPandas()
# Out:
#   Season HomeTeam  TotalHomePoints
# 0   2011  Hamburg               16

# %%
## combine home and away points: each team each season with total collected pounts
total_points = home_points.join(away_points,
                                home_points.HomeTeam == away_points.AwayTeam, 'inner').select(col('HomeTeam').alias('TeamName'),
                                                                                            home_points.Season, 
                                                                                            (col('TotalHomePoints')+col('TotalAwayPoints')).alias('TotalPoints'))

# %%
total_points.limit(10).toPandas()
# Out:
#   TeamName Season  TotalPoints
# 0  Hamburg   2015           39
# 1  Hamburg   2016           48
# 2  Hamburg   2010           46
# 3  Hamburg   2014           43
# 4  Hamburg   2013           38
# 5  Hamburg   2012           46
# 6  Hamburg   2011           36
# 7   Hertha   2014           40
# 8   Hertha   2013           39
# 9   Hertha   2011           33

# %%
## lower standard deviation indicates that the teams are more evenly matched, which can be interpreted as higher competitiveness
## standard deviation of points for each season
points_stddev = total_points.groupBy('Season').agg(round(stddev('TotalPoints'), 2).alias('PointsSD'))

# %%
color = (0.2, # redness
         0.4, # greenness
         0.2, # blueness
         0.6 # transparency
         ) 
df_SD = points_stddev.toPandas()
ax = df_SD['PointsSD'].plot(kind = 'bar',rot = 45, color = color, figsize = (12, 4))
plt.ylabel('SD/Season')
plt.xlabel('Seasons')
plt.xticks(range(len(df_SD['Season'])), df_SD['Season'])
temp = 0
# The enumerate function is used to loop over the Total_Matches column and get both the index and the value of each bar
for index, value in enumerate(df_SD['PointsSD']):
        # xy=(index, value): Specifies the position of the annotation (at the top of the bar
        # xytext=(0, 3): Offsets the text by 3 points above the bar
        # textcoords='offset points': Ensures the text is offset by the specified amount.
        # ha='center': Horizontally aligns the text in the center of the bar.
    ax.annotate(str(value), xy=(index, value), xytext = (0, 3), textcoords = 'offset points', ha = 'center')
    
plt.show()

# %%
## low sd most competative
most_compitative_season = points_stddev.orderBy('PointsSD').first()
print(most_compitative_season)
# Out:
# Row(Season='2010', PointsSD=12.97)

# %% [markdown]
# #### Frage 5: What's the best month to watch Bundesliga?

# %%
bundesliga = bundesliga.withColumn('Month', month(col('Date')))

# %%
bundesliga.limit(6).toPandas()
# Out:
#   Match_ID Div Season        Date        HomeTeam       AwayTeam  \
# 0      480  D1   2010  2010-09-21      Hoffenheim  Bayern Munich
# 1      481  D1   2010  2011-01-15       Wolfsburg  Bayern Munich
# 2      482  D1   2010  2010-12-19       Stuttgart  Bayern Munich
# 3      483  D1   2010  2011-04-23   Ein Frankfurt  Bayern Munich
# 4      484  D1   2010  2010-08-27  Kaiserslautern  Bayern Munich
# 5      485  D1   2010  2011-03-05        Hannover  Bayern Munich
#
#   Home_Team_Goal Away_Team_Goal Final_Result  HomeTeamWin  AwayTeamWin  Drow  \
# 0              1              2            A            0            1     0
# 1              1              1            D            0            0     1
# 2              3              5            A            0            1     0
# 3              1              1            D            0            0     1
# 4              2              0            H            1            0     0
# ...

# %%
# Count the number of matches per month
matches_per_month = bundesliga.groupBy('Month').count().withColumnRenamed('count', 'Match_Count')

# Sum the goals scored per month
goals_per_month = bundesliga.groupBy('Month').agg(
    sum(col('Home_Team_Goal') + col('Away_Team_Goal')).alias('Total_Goals')
)

# %%
matches_per_month.limit(10).toPandas()
# Out:
#    Month  Match_Count
# 0     12          208
# 1      1          117
# 2      3          252
# 3      5          154
# 4      9          246
# 5      4          297
# 6      8          152
# 7     10          222
# 8     11          233
# 9      2          261

# %%
# Combine match count and goals data
monthly_stats = matches_per_month.join(goals_per_month, on='Month')

# Convert to Pandas DataFrame for easier manipulation and analysis
monthly_stats_df = monthly_stats.toPandas()



# Find the month with the highest match count and highest goals
best_month_matches = monthly_stats_df.loc[monthly_stats_df['Match_Count'].idxmax()]['Month']
best_month_goals = monthly_stats_df.loc[monthly_stats_df['Total_Goals'].idxmax()]['Month']

print(f"The month with the most matches is: {best_month_matches}")
print(f"The month with the most goals scored is: {best_month_goals}")
# Out:
# The month with the most matches is: 4.0
# The month with the most goals scored is: 4.0
